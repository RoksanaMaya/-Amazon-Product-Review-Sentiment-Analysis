# %% [markdown]
# <a href="https://colab.research.google.com/github/RoksanaMaya/Amazon-Product-Review-Sentiment-Analysis/blob/main/a_DataPreparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <center><h1>Load Data</h1></center>

# %%
path = '/content/drive/MyDrive/Amazon Reviews'
data = path + '/AMAZON_FASHION.json'

# %%
df = pd.read_json(data, lines=True)

# %%
df.head().T
# Out:
#                                      0  \
# overall                              5
# verified                          True
# reviewTime                 10 20, 2014
# reviewerID              A1D4G1SNUZWQOT
# asin                        7106116521
# reviewerName                     Tracy
# reviewText      Exactly what I needed.
# summary         perfect replacements!!
# unixReviewTime              1413763200
# vote                               NaN
# style                              NaN
# image                              NaN
#
#                                                                 1  \
# overall                                                         2
# verified                                                     True
# reviewTime                                            09 28, 2014
# reviewerID                                         A3DDWDH9PX2YX2
# asin                                                   7106116521
# ...

# %%
df.tail().T
# Out:
#                                                            883631  \
# overall                                                         5
# verified                                                     True
# reviewTime                                            02 21, 2017
# reviewerID                                         A1ZSB2Q144UTEY
# asin                                                   B01HJHTH5U
# reviewerName                                      Amazon Customer
# reviewText      I absolutely love this dress!!  It's sexy and ...
# summary                              I absolutely love this dress
# unixReviewTime                                         1487635200
# vote                                                          NaN
# style                                                         NaN
# image                                                         NaN
#
#                                                            883632  \
# ...

# %% [markdown]
# <center><h1>Drop Unnecesary Data</h1></center>

# %%
df.columns
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'style', 'image'],
#       dtype='object')

# %%
df.drop(columns=['reviewerID', 'asin', 'reviewerName', 'unixReviewTime', 'vote', 'style', 'image'], inplace=True)

# %%
df.to_parquet(path+'/AMAZON_FASHION_v2.parquet', index=False)
